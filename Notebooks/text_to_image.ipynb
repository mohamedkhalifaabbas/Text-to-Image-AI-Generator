# %% [markdown]
# ## Import Libraries

# %%
pip install diffusers transformers accelerate safetensors

# %%
from diffusers import StableDiffusionPipeline
import torch
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Model

# %%
model_id = "sd-legacy/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float32)
pipe = pipe.to("cuda")

# %% [markdown]
# ## Prompts

# %%
prompt = "a photo of an astronaut riding a horse on mars"
image = pipe(prompt).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
plt.imshow(image)
plt.axis("off")
plt.show()

# %%
prompt2 = "A hyper-realistic photo of a burger with golden buns and glowing cheese"
image2 = pipe(prompt2).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
plt.imshow(image2)
plt.axis("off")
plt.show()

# %%
prompt3 = "Two friends sitting at a cozy coffee shop, having a conversation, warm lights, latte art on the table"
image3 = pipe(prompt3).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
plt.imshow(image3)
plt.axis("off")
plt.show()

# %%
prompt4 = "a teacher explaining programming on a whiteboard with Python code, students sitting with laptops, modern classroom"
image4 = pipe(prompt4).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
plt.imshow(image4)
plt.axis("off")
plt.show()
